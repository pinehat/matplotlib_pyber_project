# %% [markdown]
# # Pyber Matplotlib Project

# %% [markdown]
# Observable Trends:
#
# 1) As might be expected, Pyber revenue is most heavily concentrated in urban cities (about 2/3 of our business), less in suburban cities (about 1/3), and very low in rural cities (only about 7%). The total number of rides for each city type follows those same ratios, so there is a very strong relationship seen between total fares and total number of rides among city types. However, 81% of our drivers are in urban cities, so those drivers are producing proportionately less income than suburban or rural drivers.
#
# 2) Also as might be expected, average fares are higher in suburban cities than in urban cities.
#
# 3) In both urban and suburban cities, there are recognizable clusters of number of rides and average fares, with most urban cities having between 15 and 35 rides with average fares between $20  and  $30, and suburban cities mostly having between 10 and 25 rides, with average fares mostly between $25  and  $35. No such cluster is observed in rural cities; data is much more dispersed.
#
# 4) Our ride data runs from Jan. 1, 2018 to May 8, 2018, so if a full year's data could be obtained, we might see how weather/temperature influences outcomes (i.e., could urban cities see a pronounced change in number of rides with a change in weather?)

# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# File to Load (Remember to change these)
city_data_to_load = "data/city_data.csv"
ride_data_to_load = "data/ride_data.csv"

# Read the City and Ride Data
citydata_df = pd.read_csv(city_data_to_load)
ridedata_df = pd.read_csv(ride_data_to_load)

ridedata_df.head()
# Out:
#                  city             date   fare       ride_id
# 0  Lake Jonathanshire  1/14/2018 10:14  13.83  5.739410e+12
# 1  South Michelleport   3/4/2018 18:24  30.24  2.343910e+12
# 2  Port Samanthamouth   2/24/2018 4:29  33.44  2.005070e+12
# 3          Rodneyfort  2/10/2018 23:22  23.44  5.149250e+12
# 4          South Jack    3/6/2018 4:28  34.58  3.908450e+12

# %%
# Combine the data into a single dataset
merged_df = pd.merge(citydata_df, ridedata_df, how='inner', on='city')

# Display the data table for preview
merged_df.head()
# Out:
#           city  driver_count   type             date   fare       ride_id
# 0  Richardfort            38  Urban   2/24/2018 8:40  13.93  5.628550e+12
# 1  Richardfort            38  Urban  2/13/2018 12:46  14.00  9.100500e+11
# 2  Richardfort            38  Urban  2/16/2018 13:52  17.92  8.206390e+11
# 3  Richardfort            38  Urban   2/1/2018 20:18  10.26  9.554940e+12
# 4  Richardfort            38  Urban   4/17/2018 2:26  23.00  7.200210e+11

# %%
merged_df.tail()
# Out:
#                  city  driver_count   type             date   fare  \
# 2370      Jessicaport             1  Rural  1/31/2018 17:57  58.29
# 2371  South Saramouth             7  Rural  2/20/2018 16:32  44.29
# 2372  South Saramouth             7  Rural  1/28/2018 15:55  31.25
# 2373  South Saramouth             7  Rural  3/27/2018 21:07  11.87
# 2374  South Saramouth             7  Rural  4/12/2018 18:11  57.23
#
#            ride_id
# 2370  6.231550e+11
# 2371  3.622370e+12
# 2372  7.118050e+12
# 2373  1.703520e+11
# 2374  5.081200e+12

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
# Get x and y coordinates for city types
by_city = merged_df.groupby('city')

# Build dataframe components
avg_fare = by_city.mean()['fare']
ride_count = by_city['ride_id'].count()
driver_count = by_city.mean()['driver_count']
city_type = citydata_df.set_index('city')['type']

city_info = pd.DataFrame({
    "Number of Rides": ride_count,
    "Average Fare": avg_fare,
    "Number of Drivers": driver_count,
    "Type of City": city_type
})

city_info.sort_values('Number of Drivers', ascending = False)

rural = city_info[city_info['Type of City'] == 'Rural']
suburban = city_info[city_info['Type of City'] == 'Suburban']
urban = city_info[city_info['Type of City'] == 'Urban']

plt.figure(figsize=(6.0, 4.0))

plt.title('Pyber Ride Sharing Data 2018')

# Define X and Y limits
plt.xlim(0, 42 )
plt.ylim(17, 45 )

# Build the scatter plots for each city type
plt.scatter(urban['Number of Rides'], urban['Average Fare'], 
    s = urban['Number of Drivers']*10, color = "Coral", 
    edgecolor = 'black', label = 'Urban', alpha = .7)
plt.scatter(suburban['Number of Rides'], suburban['Average Fare'], 
    s = suburban['Number of Drivers']*10, color = "SkyBlue", 
    edgecolor = 'black', label = 'Suburban', alpha = .7)
plt.scatter(rural['Number of Rides'], rural['Average Fare'], 
    s = rural['Number of Drivers']*10, color = "Gold", 
    edgecolor = 'black', label = 'Rural', alpha = .7)

# Create a legend
lgnd = plt.legend(title = "City Types")
lgnd.legendHandles[0]._sizes = [75]
lgnd.legendHandles[1]._sizes = [75]
lgnd.legendHandles[2]._sizes = [75]

plt.grid(True)

plt.xlabel('Total Number of Rides (Per City)')
plt.ylabel('Average Fare ($)')

# Incorporate a text label regarding circle size
note = "Note:\nCircle size correlates\nwith driver count per city."
plt.gcf().text(0.925, 0.65, note, fontsize=11)

# Save Figure
plt.savefig("pyberscatterplot.png", dpi=None, facecolor='w', edgecolor='w',
        orientation='portrait', papertype=None, format=None,
        transparent=False, bbox_inches="tight", pad_inches=0.1,
        frameon=None, metadata=None)

# Show plot
plt.show()

# %% [markdown]
# ## Total Fares by City Type

# %%
# Calculate Type Percentages
fares_by_type_df = merged_df.groupby('type')['type', 'fare', 'ride_id', 'driver_count']
sum_fares = fares_by_type_df.sum()['fare']

# Build Pie Chart
labels = sum_fares.index
colors = ["Gold","SkyBlue","Coral"]
explode = [0 , 0, .3]
plt.pie(sum_fares, startangle = 110, colors = colors, explode = explode,
        labels = labels, autopct = "%1.1f%%", shadow = True, 
        wedgeprops = {'linewidth': .5, 'edgecolor': 'black'})

#pie chart display
plt.title('% of Total Fares by City Type')

# Save Figure
plt.savefig("faresbycitytype.png")

# Show Figure
plt.show()

# %% [markdown]
# ## Total Rides by City Type

# %%
# Calculate Ride Percentages
sum_rides = fares_by_type_df.count()['ride_id']

# Build Pie Chart
labels = sum_rides.index
plt.pie(sum_rides, startangle = 122, explode = explode, colors = colors, 
        labels = labels, autopct = "%1.1f%%", shadow = True, 
        wedgeprops = {'linewidth': .5, 'edgecolor': 'black'})
plt.title('% of Total Rides by City Type')

# Save Figure
plt.savefig("ridesbycitytype.png")

# Show Figure
plt.show()

# %% [markdown]
# ## Total Drivers by City Type

# %%
# Get driver percentages
sum_drivers = citydata_df.groupby('type').sum()['driver_count']

# Build chart
labels = sum_drivers.index
plt.pie(sum_drivers, startangle = 150, explode = explode, colors = colors, labels = labels, autopct = "%1.1f%%", shadow = True, wedgeprops = {'linewidth': .5, 'edgecolor': 'black'})
plt.title('% of Total Drivers by City Type')
plt.axis('equal')

# Save Figure
plt.savefig("driversbycitytype.png")

# Show Figure
plt.show()
